# %%
from pyspark.sql.functions import lower, regexp_replace, regexp_extract, col, trim, when, instr, lit, split, size, avg, isnan, when, count, isnull, mean, coalesce
from pyspark.sql.functions import concat_ws
from pyspark.sql import Window

special_char = '[^a-z0-9A-Z_ ' \
               'àáãạảăắằẳẵặâấầẩẫậèéẹẻẽêềếểễệđìíĩỉịòóõọỏôốồổỗộơớờởỡợùúũụủưứừửữựỳỵỷỹýÀÁÃẠẢĂẮẰẲẴẶÂẤẦẨẪẬ' \
               'ÈÉẸẺẼÊỀẾỂỄỆĐÌÍĨỈỊÒÓÕỌỎÔỐỒỔỖỘƠỚỜỞỠỢÙÚŨỤỦƯỨỪỬỮỰỲỴỶỸÝ]+'

# %%
from pyspark.sql import SparkSession

# Create a DataFrame using SparkSession
spark = (SparkSession
    .builder
    .appName("lazada_cleaning")
    .getOrCreate())
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/02/10 22:19:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, DoubleType, MapType

path = '/home/jazzdung/data/lazada/Thời trang & Phụ kiện Nữ/Đồng Hồ Nữ/Đồng Hồ Cao Cấp/product.ndjson'
# path = '/home/jazzdung/E-Commerce-Support-System/mr_clean/product.ndjson'

# spark.conf.set("spark.sql.caseSensitive", True)
# df = spark.read.json(path)
# spark.conf.set("spark.sql.caseSensitive", False)

# to convert attrs to String
schema = StructType([
    StructField("avg_rating", StringType(), True),
    StructField("product_name", StringType(), True),
    StructField("price", StringType(), True),
    StructField("brand_name", StringType(), True),
    StructField("num_review", StringType(), True),
    StructField("attrs", MapType(StringType(),StringType(),True)), 
    StructField("product_desc", StringType(), True),
    StructField("url", StringType(), True)
])

df = spark.read.format("json").schema(schema).load(path)


df.count()
df.printSchema()
# df.show(100, truncate=False)
# Out:
# root
#  |-- avg_rating: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- brand_name: string (nullable = true)
#  |-- num_review: string (nullable = true)
#  |-- attrs: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- product_desc: string (nullable = true)
#  |-- url: string (nullable = true)

# %%
def clean_product_name(df):
    # Lowercase
    product_name = lower(col('product_name'))

    # # Remove like tier
    # product_name = regexp_replace(product_name, 'yêu thích\n|yêu thích\+\n', ' ')

    # Remove contents inside [], option indicate promotion, prices    
    product_name = regexp_replace(product_name, r'\[.*?\]', ' ')

    # Remove contents inside [], option indicate promotion, prices    
    product_name = regexp_replace(product_name, r'\(.*?\)', ' ')

    # Remove special character
    product_name = regexp_replace(product_name, special_char, ' ')
    # Remove redundant whitespaces  
    product_name = regexp_replace(product_name, ' +', ' ')

    # Trim
    product_name = trim(product_name)
    return df.withColumn('product_name', product_name)

def clean_price(df):
    value = col('price')   
    value = regexp_replace(value, r'₫.*' , '')
    value = regexp_replace(value, '\.', '')
    value = value.cast('int')

    return df.withColumn('price', value)

def clean_brand(df):
    brand_name = lower(col('brand_name'))
    brand_name = regexp_replace(brand_name, 'no brand', 'no info')
    brand_name = regexp_replace(brand_name, special_char, ' ')
    brand_name = regexp_replace(brand_name, ' +', ' ')
    brand_name = trim(brand_name)
    return df.withColumn('brand_name', brand_name)

def clean_review(df):
    num_review = lower(col('num_review'))
    num_review = regexp_replace(num_review, 'không có đánh giá', '0')
    num_review = regexp_replace(num_review, ' đánh giá', '')
    num_review = num_review.cast('int')

    return df.withColumn('num_review', num_review)

def clean_attrs(df):
    attrs = lower(col('attrs').cast('string'))
    attrs = regexp_replace(attrs, special_char, ' ')
    attrs = regexp_replace(attrs, ' +', ' ')
    attrs = trim(attrs)
    return df.withColumn('attrs', attrs)

def clean_desc(df):
    product_desc = lower(col('product_desc'))
    product_desc = regexp_replace(product_desc, ' &amp;', ',')
    product_desc = regexp_replace(product_desc, '<svg.*?</svg>|<div>|div|class=|"|<label.*?>|<flex.*?>| href=/', '')
    product_desc = regexp_replace(product_desc, '</a>', '-')
    product_desc = regexp_replace(product_desc, '</label>', ': ')
    product_desc = regexp_replace(product_desc, '< ', '<')
    product_desc = regexp_replace(product_desc, "\/.*?\>","/>")
    product_desc = regexp_replace(product_desc, '<a ', '<')
    product_desc = regexp_replace(product_desc, '<p ', '<')

    product_desc = regexp_replace(product_desc, '</>', ' ')
    product_desc = regexp_replace(product_desc, '<.*?>', ' ')
    product_desc = regexp_replace(product_desc, '\\n', ' ')
    product_desc = regexp_replace(product_desc, special_char, ' ')

    product_desc = regexp_replace(product_desc, ' +', ' ')

    return df.withColumn('product_desc', product_desc)

# %%
df_cleaned = clean_product_name(df)
df_cleaned = clean_price(df_cleaned)
df_cleaned = clean_brand(df_cleaned)
df_cleaned = clean_review(df_cleaned)
df_cleaned = clean_attrs(df_cleaned)
df_cleaned = clean_desc(df_cleaned)
df_cleaned = df_cleaned.withColumn("avg_rating",df_cleaned["avg_rating"].cast('double'))

df_cleaned = df_cleaned.withColumnRenamed('brand_name', 'brand')
df_cleaned = df_cleaned.withColumnRenamed('product_desc', 'description')

df_cleaned.printSchema()
df_cleaned.show(10)
# Out:
# root
#  |-- avg_rating: double (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- num_review: integer (nullable = true)
#  |-- attrs: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- url: string (nullable = true)
#
# +----------+--------------------+------+---------+----------+--------------------+--------------------+--------------------+
# |avg_rating|        product_name| price|    brand|num_review|               attrs|         description|                 url|
# +----------+--------------------+------+---------+----------+--------------------+--------------------+--------------------+
# |       4.9|đồng hồ nữ đơn gi...|425000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       4.9|đồng hồ nữ đơn gi...|425000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       4.9|đồng hồ nữ đơn gi...|425000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       4.9|đồng hồ nữ đơn gi...|338000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       4.9|đồng hồ nữ đơn gi...|338000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       4.9|đồng hồ nữ đơn gi...|339000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       4.9|đồng hồ nữ đơn gi...|339000|  no info|        26|phân loại màu sắc...| sản phẩm được nh...|https://www.lazad...|
# |       5.0|louiswill đồng hồ...|270000|louiswill|        10|                    | sản phẩm được nh...|https://www.lazad...|
# |       4.7|đồng hồ thông min...|350000| picetech|        11|            nhóm màu|                none|https://www.lazad...|
# |       4.7|đồng hồ thông min...|350000| picetech|        11|   nhóm màu sr7 hồng|                none|https://www.lazad...|
# +----------+--------------------+------+---------+----------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
clean_product_name(df).select("product_name").distinct().show(100, truncate=False)
clean_price(df).select("price").distinct().show(100, truncate=False)
clean_brand(df).select("brand_name").distinct().show(100, truncate=False)
clean_review(df).select("num_review").distinct().show(100, truncate=False)
clean_attrs(df).select("attrs").distinct().show(100, truncate=False)


clean_desc(df).select("url", "product_desc").distinct().show(100, truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |product_name                                                                                                                                                                                                                                         |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |đồng hồ nữ pha lê thời trang đồng hồ kim cương vòng tay nữ thường ngày thương hiệu cao cấp hàng đầu đồng hồ pha lê rhinestone casual đồng hồ đeo tay                                                                                                 |
# |louiswill đồng hồ nữ đồng hồ thạch anh thời trang đồng hồ kim cương đồng hồ dây thép đồng hồ chống nước 30m đồng hồ dây mỏng đồng hồ mặt số la mã đồng hồ thiết kế sang trọng đồng hồ đeo tay                                                        |
# |đồng hồ nữ đẹp thơi trangdây kim loại bbr 9881thép không gỉ size 34mm đồng hồ nữ mặt tròn đồng hồ nữ chống nước                                                                                                                                      |
# |đồng hồ thông minh sr8 smartwatch chống nước kết nối bluetooth nghe gọi nhận thông báo chính hãng picetech                                                                                                                                           |
# |louiswill đồng hồ nữ đồng hồ mặt số vuông retro đồng hồ dây pu thường ngày đồng hồ thạch anh đồng hồ siêu mỏng thời trang đồng hồ gương nhiều góc đồng hồ chống nước 3atm đồng hồ đeo tay doanh nhân quà tặng thanh lịch                             |
# |đồng hồ nữ màu hồng anh đào siêu hot ins đồng hồ dễ phối sành điệu trái tim thiếu nữ cổ điển dạ quang đáng yêu đơn giản dạ quang học sinh                                                                                                            |
# |đồng hồ nữ sheeder mặt vuông dây da cao cấp size 36mm                                                                                                                                                                                                |
# |louiswill đồng hồ nữ đồng hồ dây pu cổ điển thời trang đồng hồ thạch anh đồng hồ siêu mỏng đồng hồ kim cương ngôi sao đồng hồ chống nước 3atm đồng hồ đeo tay công sở thường ngày có kim dạ quang                                                    |
# |louiswill đồng hồ thời trang nữ chống nước cao cấp                                                                                                                                                                                                   |
# |đồng hồ nữ viser dây da cao cấp mặt vuông                                                                                                                                                                                                            |
# |mặt dây chuyền hình trái tim đồng hồ đeo tay kiểu vòng tay dây xích nữ mặt đồng hồ nhỏ học sinh khí chất đơn giản nữ tinh xảo nhỏ nhắn                                                                                                               |
# |louiswill đồng hồ nữ đồng hồ thạch anh retro đồng hồ kim cương đồng hồ dây thép đồng hồ chống nước 30m đồng hồ dây mỏng đồng hồ mặt số la mã đồng hồ thiết kế sang trọng đồng hồ đeo tay quà tặng thanh lịch                                         |
# |đồng hồ thông minh bản sr 7 viền thép nghe gọi tập luyện thể thao nhận thông báo chính hãng picetech                                                                                                                                                 |
# |louiswill đồng hồ nữ đồng hồ đeo tay dây pu cổ điển thường ngày đồng hồ thạch anh đồng hồ siêu mỏng thời trang đồng hồ kim cương ngôi sao đồng hồ chống nước 3atm đồng hồ đeo tay doanh nhân                                                         |
# |17 dặm phụ nữ thời trang đầy sao kim cương da đồng hồ đồng hồ thường không thấm nước analog đồng hồ phụ kiện quà tặng                                                                                                                                |
# |đồng hồ đeo tay đồng hồ dây da cảm giác cao cấp cổ điển cho nữ cấp hai học sinh khí chất đơn giản hơi xa xỉ thiết kế thiểu số instagram mẫu nữ                                                                                                       |
# |đồng hồ đeo tay phong cách anh cho nữ mặt to hình vuông cảm giác cao cấp ít người xa xỉ nhẹ nhàng sành điệu thời trang cổ điển mẫu mới năm 2022                                                                                                      |
# |đồng hồ đeo tay nữ sinh mẫu n đơn giản đáng yêu nữ is tươi mới phong cách nhật bản trẻ em thiếu nữ học sinh cấp hai đá 1 đồng hồ anh                                                                                                                 |
# |đồng hồ đeo tay vòng tay phong cách chanel cảm giác cao cấp đồng hồ xanh lá mặt nhỏ thời trang đơn giản thiết kế thiểu số instagram cho nữ phong cách hồng kông cổ điển                                                                              |
# |đồng hồ thời trang nữ học sinh mẫu nữ sành điệu thời trang cổ điển ít người biết hơi xa hoa cao cấp phong cách normcore thiểu số ưa chuộng nước pháp                                                                                                 |
# |6 7 8 9 10 11 12 tuổi đồng hồ thạch anh chống nước hoạt hình đáng yêu cho bé gái học sinh cấp 2 học sinh tiểu học trẻ em học sinh tiểu học                                                                                                           |
# |louiswill đồng hồ nữ đồng hồ dây da chính hãng đồng hồ thạch anh nữ thời trang đồng hồ đeo tay đồng hồ chức năng dạ quang mặt thiên nga đồng hồ cân kim cương đơn giản chống nước 3 amt cho nữ                                                       |
# |đồng hồ bầu trời đầy sao đồng hồ nữ đồng hồ ngôi sao đầy sao đồng hồ dây đeo nam châm đồng hồ thép không gỉ đồng hồ hàn quốc đồng hồ ngôi sao thời trang đồng hồ bầu trời đầy sao đồng hồ ngôi sao đầy sao                                           |
# |đồng hồ nữ dây da qianba thời trang chính hãng                                                                                                                                                                                                       |
# |louiswill đồng hồ đeo tay nữ đồng hồ nữ thể thao đồng hồ thời không thấm nước phong cách hàn quốc mềm mỏng nữtính đồng hồ thạch anh đồng hồ nu đẹp chống nước đồng hồ nữ chính hãng cao cấp                                                          |
# |đồng hồ led điện tử đeo tay nam nữ thời trang mặt vuông kiểu dáng thể thao mặt vòng cung đh2                                                                                                                                                         |
# |đồng hồ thạch anh chuyên dùng cho công chức đồng hồ quả quýt đi thi cho nam đồng hồ treo túi tiện lợi cho y tá móc mini học sinh số lớn                                                                                                              |
# |đồng hồ đeo tay đồng hồ nữ dễ phối sành điệu thời trang thiết kế dành cho số ít người có mặt trong thiết kế màu bạc cá tính đơn giản cao cấp cho nữ                                                                                                  |
# |louiswill đồng hồ nữ đồng hồ rỗng hình trái tim thời trang đồng hồ dát kim cương có lịch đồng hồ chống nước 30m đồng hồ q dạ quang đồng hồ thạch anh đồng hồ dây thép                                                                                |
# |louiswill đồng hồ nữ đồng hồ thạch anh chính hãng dây da đồng hồ milanese lưới đồng hồ thép 30m đồng hồ chống nước dây đeo mỏng đồng hồ chữ số la mã đồng hồ mặt số sang trọng đồng hồ thiết kế đồng hồ đeo tay quà tặng thanh lịch cho phụ nữ phụ nữ|
# |louiswill women fashion watch sports quartz women watches 30m waterproof women wristwatches business stainless steel band watches female casual watches with free band remover                                                                       |
# |đồng hồ đeo tay thiết kế dành cho số ít người đồng hồ thạch anh thời trang cho nữ màu vàng hồng cảm giác cao cấp sang trọng cho học sinh khí chất đơn giản                                                                                           |
# |đồng hồ nữ đơn giản sản phẩm chính hãng julius đồng hồ thời trang dây da màu xanh lá tươi mới đồng hồ nữ cổ điển phong cách hàn đồng hồ học sinh                                                                                                     |
# |nữ dễ thương đồng hồ dạ quang nhật bản retro trung học hàn quốc cho học sinh xu hướng đơn giản ins college wind đồng hồ chống nước                                                                                                                   |
# |đồng hồ nữ pha lê kim cương sang trọng đồng hồ nữ đồng hồ thạch anh thời trang                                                                                                                                                                       |
# |17 mile thời trang đồng hồ đeo tay hoa kim cương thạch anh đơn giản đồng hồ mặt tròn giản dị phụ nữ không thấm nước phụ kiện đồng hồ kỹ thuật số                                                                                                     |
# |17 dặm 3 cái bộ thời trang thạch anh kim cương hoa cổ tay xem đồng hồ tròn đơn giản đồng hồ nữ kỹ thuật số chống nước phụ kiện                                                                                                                       |
# |louiswill đồng hồ cho nữ thiết kế mới đồng hồ đeo tay kim cương thời trang đồng hồ tròn đơn giản thường ngày đồng hồ nữ kỹ thuật số chống nước phụ kiện đồng hồ dây da mỏng cho nữ                                                                   |
# |đồng hồ đường vuông nhỏ đồng hồ đeo tay cổ điển đơn giản phong cách hàn quốc học sinh nữ dây nhỏ xinh nhỏ gọn chống nước phong cách instagram mẫu mới khí chất                                                                                       |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# +------+
# |price |
# +------+
# |135000|
# |145000|
# |114000|
# |350000|
# |91000 |
# |270000|
# |63000 |
# |99000 |
# |19000 |
# |100000|
# |88000 |
# |54600 |
# |141000|
# |38000 |
# |34000 |
# |142000|
# |338000|
# |62786 |
# |120000|
# |28000 |
# |251000|
# |294000|
# |127000|
# |34985 |
# |126000|
# |96000 |
# |64000 |
# |425000|
# |31000 |
# |139000|
# |133000|
# |152000|
# |47000 |
# |128000|
# |1000  |
# |41000 |
# |216000|
# |299000|
# |221000|
# |155000|
# |137000|
# |156000|
# |165000|
# |46000 |
# |84000 |
# |69000 |
# |59000 |
# |339000|
# |108000|
# |34400 |
# |140000|
# |51000 |
# |62000 |
# |89000 |
# +------+
#
# +----------+
# |brand_name|
# +----------+
# |17 mile   |
# |oem       |
# |louiswill |
# |picetech  |
# |no info   |
# +----------+
#
# +----------+
# |num_review|
# +----------+
# |31        |
# |28        |
# |26        |
# |12        |
# |47        |
# |16        |
# |3         |
# |20        |
# |57        |
# |15        |
# |17        |
# |9         |
# |4         |
# |55        |
# |10        |
# |50        |
# |38        |
# |113       |
# |156       |
# |29        |
# |338       |
# |32        |
# |11        |
# |33        |
# |68        |
# |14        |
# |135       |
# |2         |
# |365       |
# |30        |
# |0         |
# +----------+
#
# +-----------------------------------------------------------------------------------------------------------------------------------+
# |attrs                                                                                                                              |
# +-----------------------------------------------------------------------------------------------------------------------------------+
# |màu sắc dây đồng hồ set1 2 bracelet                                                                                                |
# |phân loại màu sắc silicon xanh hộp đen tinh xảo pin dự phòng                                                                       |
# |màu sắc dây đồng hồ hồng                                                                                                           |
# |phân loại màu sắc màu đỏ có vỏ màu nâu kiểu thắt lưng da                                                                           |
# |phân loại màu sắc                                                                                                                  |
# |phân loại màu sắc phong cách tối giản nước sốt kẻ ca rô mẫu mới gói bong bóng giảm xóc hai tầng màu xanh gió nhẹ pin dự phòng      |
# |màu sắc dây đồng hồ đen full                                                                                                       |
# |phân loại màu sắc silicone màu nâu hộp đen tinh xảo pin dự phòng                                                                   |
# |phân loại màu sắc da màu đen tăng mặt vàng                                                                                         |
# |phân loại màu sắc xám kèm đồng hồ đeo tay vòng tay mặt dây chuyền hoa đào hộp tiên nữ                                              |
# |phân loại màu sắc đai xanh đậm hộp quà vòng tay anh đào                                                                            |
# |phân loại màu sắc hồng kèm đồng hồ pin                                                                                             |
# |phân loại màu sắc thắt lưng màu đỏ hộp đen tinh xảo pin dự phòng                                                                   |
# |phân loại màu sắc hồng kèm đồng hồ đeo tay vòng tay mặt dây chuyền hoa đào hộp tiên nữ                                             |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới gói màu tím hai lớp bong bóng giảm xóc pin dự phòng                  |
# |màu sắc dây đồng hồ set1 11 watch                                                                                                  |
# |phân loại màu sắc màu trắng loại lớn quà tặng pin hộp đồng hồ go                                                                   |
# |màu sắc dây đồng hồ set1 1 box                                                                                                     |
# |màu sắc dây đồng hồ set2 3 watch bracelet                                                                                          |
# |phân loại màu sắc mặt đen mẫu dây lưới                                                                                             |
# |màu sắc dây đồng hồ 5                                                                                                              |
# |màu sắc dây đồng hồ gold                                                                                                           |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới vanilla green hộp màu xám best pin quà tặng nhỏ ngẫu nhiên           |
# |phân loại màu sắc mặt dây chuyền bạc                                                                                               |
# |nhóm màu sr7 hồng                                                                                                                  |
# |phân loại màu sắc vỏ bạc mặt hồng                                                                                                  |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới màu tím oải hương hộp màu xám best pin dây đeo tay quả hồng như ý    |
# |phân loại màu sắc màu vàng hồng                                                                                                    |
# |màu sắc dây đồng hồ rose gold white                                                                                                |
# |phân loại màu sắc màu đen loại lớn hộp đồng hồ pin quà tặng go                                                                     |
# |màu sắc dây đồng hồ 4                                                                                                              |
# |màu sắc dây đồng hồ dây nâu mặt nâu                                                                                                |
# |phân loại màu sắc quai màu xám hộp quà vòng tay anh đào                                                                            |
# |phân loại màu sắc đồng hồ đeo tay dây xanh hộp kiểu tiên nữ pin                                                                    |
# |màu sắc dây đồng hồ red calendar                                                                                                   |
# |phân loại màu sắc màu vàng hồng kiểu có dây thép                                                                                   |
# |màu sắc dây đồng hồ black belt                                                                                                     |
# |phân loại màu sắc cà phê kèm đồng hồ pin                                                                                           |
# |màu sắc dây đồng hồ set2 5 watch bracelet                                                                                          |
# |phân loại màu sắc thắt lưng da màu cam hộp đen tinh xảo pin dự phòng                                                               |
# |nhóm màu sr8 trắng                                                                                                                 |
# |màu sắc dây đồng hồ set3 8 watch bracelet box                                                                                      |
# |phân loại màu sắc màu xám kèm đồng hồ hộp kiểu tiên nữ pin                                                                         |
# |phân loại màu sắc đĩa xanh bộ điều chỉnh đồng hồ hộp hoa pin dự phòng                                                              |
# |phân loại màu sắc đai trắng hộp quà vòng tay anh đào                                                                               |
# |phân loại màu sắc màu xám kiểu nhỏ hộp đồng hồ quà tặng pin go                                                                     |
# |màu sắc dây đồng hồ blue                                                                                                           |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới màu xanh vanilla hộp màu xám best pin dây đeo tay quả hồng như ý     |
# |phân loại màu sắc mặt trắng mẫu dây lưới                                                                                           |
# |màu sắc dây đồng hồ set3 5 watch bracelet box                                                                                      |
# |phân loại màu sắc thắt lưng da màu nâu hộp đen tinh xảo pin dự phòng                                                               |
# |màu sắc dây đồng hồ set3 6 watch bracelet box                                                                                      |
# |màu sắc dây đồng hồ 7                                                                                                              |
# |phân loại màu sắc bảng đen bộ điều chỉnh đồng hồ hộp hoa pin dự phòng                                                              |
# |màu sắc dây đồng hồ set3 2 watch bracelet box                                                                                      |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới màu đen cổ điển hộp màu xám best pin dây đeo tay quả hồng như ý      |
# |màu sắc dây đồng hồ set1 9 watch                                                                                                   |
# |màu sắc dây đồng hồ set2 6 watch bracelet                                                                                          |
# |màu sắc dây đồng hồ vàng hồng                                                                                                      |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới trà sữa hạnh nhân gói bong bóng giảm xóc hai lớp pin dự phòng        |
# |màu sắc dây đồng hồ set1 3 watch                                                                                                   |
# |phân loại màu sắc màu đen khay trắng                                                                                               |
# |màu sắc dây đồng hồ set2 7 watch bracelet                                                                                          |
# |phân loại màu sắc mặt đen mẫu dây thép                                                                                             |
# |màu sắc dây đồng hồ set3 9 watch bracelet box                                                                                      |
# |màu sắc dây đồng hồ vàng mặt vàng                                                                                                  |
# |phân loại màu sắc trắng kèm ốp lưng vàng hồng mẫu dây da                                                                           |
# |màu sắc dây đồng hồ 8                                                                                                              |
# |phân loại màu sắc màu xanh lá kiểu thắt lưng da                                                                                    |
# |phân loại màu sắc đen kèm đồng hồ pin                                                                                              |
# |phân loại màu sắc màu đen kiểu nhỏ hộp đồng hồ pin quà tặng go                                                                     |
# |phân loại màu sắc màu nâu loại lớn quà tặng pin hộp đồng hồ go                                                                     |
# |phân loại màu sắc màu bạc khay trắng                                                                                               |
# |phân loại màu sắc phong cách tối giản nước sốt kẻ ca rô mẫu mới màu xanh gió nhẹ hộp màu xám best pin dây đeo tay quả hồng như ý   |
# |phân loại màu sắc màu trắng bạc kiểu dây thép                                                                                      |
# |màu sắc dây đồng hồ rose gold                                                                                                      |
# |màu sắc dây đồng hồ đỏ                                                                                                             |
# |phân loại màu sắc đầm dự tiệc màu đỏ đô tấm trắng hộp hoa tặng kèm pin dự phòng                                                    |
# |phân loại màu sắc da màu nâu rose mặt vàng                                                                                         |
# |phân loại màu sắc đai xanh nhạt hộp quà vòng tay anh đào                                                                           |
# |màu sắc dây đồng hồ xám                                                                                                            |
# |màu sắc dây đồng hồ set2 1 watch bracelet                                                                                          |
# |màu sắc dây đồng hồ đen                                                                                                            |
# |màu sắc dây đồng hồ set1 8 watch                                                                                                   |
# |phân loại màu sắc màu xám loại lớn quà tặng pin hộp đồng hồ go                                                                     |
# |phân loại màu sắc màu trắng bạc kiểu dây thép 1                                                                                    |
# |màu sắc dây đồng hồ nâu                                                                                                            |
# |màu sắc dây đồng hồ set1 4 watch                                                                                                   |
# |phân loại màu sắc cảm giác thiết kế nước sốt kẻ ca rô mẫu mới màu mơ trà sữa hộp màu xám best pin dây đeo tay quả hồng như ý       |
# |phân loại màu sắc thắt lưng màu đen hộp đen tinh xảo pin dự phòng                                                                  |
# |phân loại màu sắc vỏ bạc mặt trắng                                                                                                 |
# |màu sắc dây đồng hồ 6                                                                                                              |
# |phân loại màu sắc đai đen tấm trắng hộp hoa tặng kèm pin dự phòng                                                                  |
# |phân loại màu sắc màu trắng kiểu nhỏ quà tặng pin hộp đồng hồ go                                                                   |
# |phân loại màu sắc khay cà phê bộ điều chỉnh đồng hồ hộp hoa pin dự phòng                                                           |
# |phân loại màu sắc đai đen tấm màu đen hộp hoa tặng kèm pin dự phòng                                                                |
# |phân loại màu sắc màu đỏ loại lớn quà tặng pin hộp đồng hồ go                                                                      |
# |màu sắc dây đồng hồ 9                                                                                                              |
# |phân loại màu sắc đai hồng hộp quà vòng tay anh đào                                                                                |
# |phân loại màu sắc phong cách tối giản nước sốt kẻ ca rô mẫu mới gói bong bóng giảm xóc hai lớp màu xanh lá cây vanilla pin dự phòng|
# +-----------------------------------------------------------------------------------------------------------------------------------+
# only showing top 100 rows
#
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |url                                                                                                                                                                                                                                                                                                  |product_desc                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |https://www.lazada.vn/products/17-dam-3-caibo-thoi-trang-thach-anh-kim-cuong-hoa-co-tay-xem-dong-ho-tron-don-gian-dong-ho-nu-ky-thuat-so-chong-nuoc-phu-kien-mua-dong-ho-nhan-vong-deo-tay-va-hop-i1261148173.html                                                                                   | sản phẩm được nhập trực tiếp từ nước ngoài hoá đơn bán hàng không được hỗ trợ trong trường hợp này các hàng hóa trong cửa hàng đều có sẵn trong kho có hàng trên kệ bạn có thể đặt hàng trực tiếp thông số kỹ thuật của sản phẩm có thể tham khảo hình ảnh cửa hàng hoặc nội dung sản phẩm do cài đặt màn hình khác nhau có thể có hiện tượng quang sai màu giữa ảnh và vật thể thực tế khoảng 2 3 ngày làm việc để gửi đi nếu bạn có bất kỳ câu hỏi nào sau khi nhận hàng vui lòng liên hệ với chúng tôi và chúng tôi sẽ giúp bạn sớm nhất có thể nếu bạn thích sản phẩm của chúng tôi hãy theo dõi chúng tôi cảm ơn bạn mô tả sản phẩm hàng mới 100 và ch
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |https://www.lazada.vn/products/17-dam-3-caibo-thoi-trang-thach-anh-kim-cuong-hoa-co-tay-xem-dong-ho-tron-don-gian-dong-ho-nu-ky-thuat-so-chong-nuoc-phu-kien-mua-dong-ho-nhan-vong-deo-tay-va-hop-i1261148173.html                                                                                   | sản phẩm được nhập trực tiếp từ nước ngoài hoá đơn bán hàng không được hỗ trợ trong trường hợp này các hàng hóa trong cửa hàng đều có sẵn trong kho có hàng trên kệ bạn có thể đặt hàng trực tiếp thông số kỹ thuật của sản phẩm có thể tham khảo hình ảnh cửa hàng hoặc nội dung sản phẩm do cài đặt màn hình khác nhau có thể có hiện tượng quang sai màu giữa ảnh và vật thể thực tế khoảng 2 3 ngày làm việc để gửi đi nếu bạn có bất kỳ câu hỏi nào sau khi nhận hàng vui lòng liên hệ với chúng tôi và chúng tôi sẽ giúp bạn sớm nhất có thể nếu bạn thích sản phẩm của chúng tôi hãy theo dõi chúng tôi cảm ơn bạn mô tả sản phẩm hàng mới 100 và chất lượng cao vật tư ngoài kệ phong cách đồng hồ đeo tay hoa kim cương thạch anh thường ngày thời trang màu sắc như hình giới tính nữ nữ loại sang trọng thời trang chất liệu thạch anh zircon thép không gỉ da loại đồng hồ analog hình dạng tròn thiết kế hoa dịp lễ quà kỷ niệm tiệc đóng gói 1 chiếc đồng hồ vòng đeo tay và hộp đặc tính sản phẩm 17 dặm 3 cái thương hiệu 17 mile sku 1261148173_vnamz 4742503058 tính năng đồng hồ pha lê chất liệu dây đeo da loại bảo hành không bảo hành bộ máy đồng hồ thạch anh hình dáng mặt đồng hồ tròn bộ sản phẩm gồm 1pcs watch bracelet and box                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |https://www.lazada.vn/products/mat-day-chuyen-hinh-trai-tim-dong-ho-deo-tay-kieu-vong-tay-day-xich-nu-mat-dong-ho-nho-hoc-sinh-khi-chat-don-gian-nu-tinh-xao-nho-nhan-i1847460993.html                                                                                                               | sản phẩm được nhập trực tiếp từ nước ngoài hoá đơn bán hàng không được hỗ trợ trong trường hợp này cửa hàng gửi shentong express tặng điện tử dự phòng hộp quà tinh xảo mặt dây chuyền nhỏ kim thép thay đổi dây đồng hồ sinh hoạt không thấm nước không thấm nước bắn tung tóe mưa bụi không được rửa trực tiếp ngâm nước nhé đặc tính sản phẩm mặt dây chuyền hình trái tim đồng hồ đeo tay kiểu vòng tay dây xích nữ mặt đồng hồ nhỏ học sinh khí chất đơn giản nữ tinh xảo nhỏ nhắn thương hiệu no brand sku 1847460993_vnamz 8362922897 waterproof_depth 3atm bộ máy đồng hồ thạch anh độ dày thảm 7mm đường kính quay số 20mm trở xuống mẫu cyd955moq ứng dụng đối tượng nữ chất liệu dây đeo white gold loại bảo hành không bảo hành                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 100 rows

# %%
desc_df = df.select("product_desc")
# desc_df.show(100, truncate=False)
df.printSchema()
# df.show(100, truncate=False)
# Out:
# root
#  |-- avg_rating: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- brand_name: string (nullable = true)
#  |-- num_review: string (nullable = true)
#  |-- attrs: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- product_desc: string (nullable = true)
#  |-- url: string (nullable = true)

# %% [markdown]
# # Implement

# %%
df_cleaned = df_cleaned.withColumn("avg_rating",df_cleaned["avg_rating"].cast('double'))
